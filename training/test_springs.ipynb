# %%
import numpy as np
import matplotlib.pyplot as plt

import cuqi
from cuqi.testproblem import Deconvolution1D, Deconvolution2D
from cuqi.distribution import JointDistribution, Gaussian, CMRF, LMRF, GMRF
from cuqi.sampler import LinearRTO, pCN, CWMH, ULA, MALA, NUTS, MH
from cuqi.problem import BayesianProblem

# %% [markdown]
# # Simple spring system

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The data $y$ is a random variable containing the temperature measurements everywhere in the domain at the final time $\tau^\mathrm{max}$ corrupted by Gaussian noise:
#
# $$u = \mathbf{K}(k) + \epsilon$$
#
# In this example, the forward model is the solution to the finite element equations: $\bm{u}=\mathbf{K}(k)^{-1}\bm{f}$ that maps the external force vector, $\bm{f}$, to the displacement vecotr $\bm{u}$, and $\epsilon$ is the measurement noise.

# %% [markdown]
# ## Three springs connected

# %% [markdown]
# Define the forward model $\bm{u}=\mathbf{K}^{-1}\bm{f}$

# %%
#This can be any function representing the forward computation. Here just a random function with 3 inputs and 2 outputs
def my_func(k):
    k = float(k)
    f = np.array([0.0, 0.0, 7.0])
    K = np.array(
        [[2.0*k    , -k       , 0.0     ],
         [-k     , 2*k      , -k   ],
         [0.0      , -k       , k    ]])
    u = np.linalg.solve(K, f)
    return u

# %%
model_func = cuqi.model.Model(my_func, range_geometry=3, domain_geometry=1)
print(model_func)
# Out:
# CUQI Model: _DefaultGeometry1D(1,) -> _DefaultGeometry1D(3,).
#     Forward parameters: ['k'].

# %%
model_func(10000)
# Out:
# array([0.0007, 0.0014, 0.0021])

# %% [markdown]
# Generate some measured (fake) data, by setting a true value and assume some distribution on the noise

# %%
k_true = 100
u_true = model_func(k_true)
u_measure = u_true + 0.01*np.random.randn(3)

# %% [markdown]
# Plot the measured (fake) data

# %%
fig, ax = plt.subplots()
ax.plot(u_measure, label='u_measure')
ax.plot(u_true, label='u_true')
ax.set_xlabel('Measure point: $i$')
ax.legend()

# %% [markdown]
# Define prior

# %%
k = cuqi.distribution.Gaussian(k_true, 10)

# %% [markdown]
# Given the noise
# \begin{align*}
# \mathbf{e} &\sim \mathrm{Gaussian}(\mathbf{0}, s_\mathbf{e}^2 \mathbf{I}).
# \end{align*}
# the likelihood becomes:
# \begin{align*}
# \pi( \bm{u} \mid k ) &\sim \mathrm{Gaussian}(\mathbf{K}(k)^{-1}\bm{f}, s_\mathbf{u}^2 \mathbf{I}),
# \end{align*}

# %%
s_u = 0.1
u = cuqi.distribution.Gaussian(model_func(k), s_u)

# %%
joint = JointDistribution(u, k)

# %% [markdown]
# The posterior distribution pdf is given by the Bayes rule:
# $$ p(x|y=y^\text{obs}) \propto p(y=y^\text{obs}|x)p(x) $$
# By setting $y=\texttt{data}$ in the joint distribution we obtain the posterior distribution:

# %%
posterior = joint(u=u_measure)
print(posterior)
# Out:
# Posterior(
#     Equation:
# 	 p(k|u) ∝ L(k|u)p(k)
#     Densities:
# 	u ~ CUQI Gaussian Likelihood function. Parameters ['k'].
#  	k ~ CUQI Gaussian.
#  )

# %%
posterior.logpdf(10)
# Out:
# array([-434.10497053])

# %%
MySampler = MH(posterior)

# %%
posterior_samples = MySampler.sample_adapt(int(1e3))
# Out:
# Sample 1000 / 1000
#
# Average acceptance rate: 0.872 MCMC scale: 1

# %%
posterior_samples.plot_trace()
# Out:
# array([[<Axes: title={'center': 'v'}>, <Axes: title={'center': 'v'}>]],
#       dtype=object)

# %%
posterior_sample_burnthin = posterior_samples.burnthin(300, 3)

# %%
posterior_sample_burnthin.plot_trace()
# Out:
# array([[<Axes: title={'center': 'v'}>, <Axes: title={'center': 'v'}>]],
#       dtype=object)

# %% [markdown]
# Alternatively, the burn-in phase can be reduced by specifying a suitable initial guess:

# %%
MySampler = MH(posterior,x0=75)
posterior_samples = MySampler.sample_adapt(int(1e3))
posterior_samples.plot_trace()
# Out:
# Sample 1000 / 1000
#
# Average acceptance rate: 0.877 MCMC scale: 1
# array([[<Axes: title={'center': 'v'}>, <Axes: title={'center': 'v'}>]],
#       dtype=object)

# %%
posterior_samples.plot_ci()
# Out:
# [<matplotlib.lines.Line2D at 0x7f8cb5343010>,
#  None,
#  <matplotlib.collections.PolyCollection at 0x7f8cb5342e60>]

# %%
posterior_samples.plot_ci(95, exact=u_true)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/mtaho/Code/Courses/CUQI_TrainingCourse/CUQIpy-demos/training/test_springs.ipynb Cell 29 line 1
# ----> <a href='vscode-notebook-cell:/home/mtaho/Code/Courses/CUQI_TrainingCourse/CUQIpy-demos/training/test_springs.ipynb#Y126sZmlsZQ%3D%3D?line=0'>1</a> posterior_samples.plot_ci(95, exact=u_true)
#
# File ~/.local/lib/python3.10/site-packages/cuqi/samples/_samples.py:546, in Samples.plot_ci(self, percent, exact, plot_envelope_kwargs, *args, **kwargs)
#     544         lex = exact.plot(*args, **kwargs)
#     545     else:
# --> 546         lex = self.geometry.plot(exact, *args, **kwargs)
#     547     plt.legend([lmn[0], lex[0], lci], [
#     548                "Mean", "Exact", f"{percent}% Credibility Interval"])
#     549 else:
#
# File ~/.local/lib/python3.10/site-packages/cuqi/geometry/_geometry.py:138, in Geometry.plot(self, values, is_par, plot_par, **kwargs)
#     135 if is_par:
#     136     values = self.par2fun(values)
# --> 138 return self._plot(values, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/cuqi/geometry/_geometry.py:398, in Continuous1D._plot(self, values, *args, **kwargs)
#     397 def _plot(self, values, *args, **kwargs):
# --> 398     p = plt.plot(self.grid, values, *args, **kwargs)
#     399     self._plot_config()
#     400     return p
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/pyplot.py:3578, in plot(scalex, scaley, data, *args, **kwargs)
#    3570 @_copy_docstring_and_deprecators(Axes.plot)
#    3571 def plot(
#    3572     *args: float | ArrayLike | str,
#    (...)
#    3576     **kwargs,
#    3577 ) -> list[Line2D]:
# -> 3578     return gca().plot(
#    3579         *args,
#    3580         scalex=scalex,
#    3581         scaley=scaley,
#    3582         **({"data": data} if data is not None else {}),
#    3583         **kwargs,
#    3584     )
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1721, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1478 """
#    1479 Plot y versus x as lines and/or markers.
#    1480
#    (...)
#    1718 (``'green'``) or hex strings (``'#008000'``).
#    1719 """
#    1720 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1721 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1722 for line in lines:
#    1723     self.add_line(line)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axes/_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axes/_base.py:499, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     496     axes.yaxis.update_units(y)
#     498 if x.shape[0] != y.shape[0]:
# --> 499     raise ValueError(f"x and y must have same first dimension, but "
#     500                      f"have shapes {x.shape} and {y.shape}")
#     501 if x.ndim > 2 or y.ndim > 2:
#     502     raise ValueError(f"x and y can be no greater than 2D, but have "
#     503                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (1,) and (3,)
